# %%
import xgboost as xgb

# You can then load the model later with:
loaded_model = xgb.Booster()
loaded_model.load_model("my_xgb_model.model")

# %%
import pandas as pd

# %%
df_flights_test = pd.read_csv('df_flights_test.csv')

# %%
df_flights_test.shape
# Out:
# (300000, 21)

# %%
df_flights_test.mkt_unique_carrier.value_counts()
# Out:
# AA    78777
# DL    63728
# UA    58920
# WN    49622
# AS    16643
# B6    11175
# NK     8006
# F9     5800
# G4     3766
# HA     3563
# Name: mkt_unique_carrier, dtype: int64

# %%
df_flights_test[['mkt_unique_carrier']] = df_flights_test[['mkt_unique_carrier']].apply(lambda col: pd.factorize(col, sort=True)[0])

# %%
df_flights_test.mkt_unique_carrier.value_counts()
# Out:
# 0    78777
# 3    63728
# 8    58920
# 9    49622
# 1    16643
# 2    11175
# 7     8006
# 4     5800
# 5     3766
# 6     3563
# Name: mkt_unique_carrier, dtype: int64

# %%
df_flights_test.head(2)
# Out:
#    Unnamed: 0     fl_date  mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0  2020-01-01                   9                 WN          WN
# 1           1  2020-01-01                   9                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
#
#    origin_airport_id  ... origin_city_name dest_airport_id  dest  \
# 0              13891  ...      Ontario, CA           14771   SFO
# 1              13891  ...      Ontario, CA           14771   SFO
#
#       dest_city_name crs_dep_time  crs_arr_time  dup crs_elapsed_time  \
# 0  San Francisco, CA         1810          1945    N               95
# 1  San Francisco, CA         1150          1320    N               90
#
#    flights  distance
# 0        1       363
# 1        1       363
#
# [2 rows x 21 columns]

# %%
df_flights_test['fl_date'] = pd.to_datetime(df_flights_test['fl_date'])
df_flights_test['weekday'] = df_flights_test['fl_date'].dt.dayofweek
df_flights_test.head()
# Out:
#    Unnamed: 0    fl_date  mkt_unique_carrier branded_code_share mkt_carrier  \
# 0           0 2020-01-01                   9                 WN          WN
# 1           1 2020-01-01                   9                 WN          WN
# 2           2 2020-01-01                   9                 WN          WN
# 3           3 2020-01-01                   9                 WN          WN
# 4           4 2020-01-01                   9                 WN          WN
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                5888                WN   N951WN               5888
# 1                6276                WN   N467WN               6276
# 2                4598                WN   N7885A               4598
# 3                4761                WN   N551WN               4761
# 4                5162                WN   N968WN               5162
#
#    origin_airport_id  ... dest_airport_id dest     dest_city_name  \
# 0              13891  ...           14771  SFO  San Francisco, CA
# 1              13891  ...           14771  SFO  San Francisco, CA
# 2              13891  ...           14831  SJC       San Jose, CA
# 3              13891  ...           14831  SJC       San Jose, CA
# 4              13891  ...           14831  SJC       San Jose, CA
#
#   crs_dep_time crs_arr_time  dup  crs_elapsed_time flights  distance  weekday
# 0         1810         1945    N                95       1       363        2
# 1         1150         1320    N                90       1       363        2
# 2         2020         2130    N                70       1       333        2
# 3         1340         1455    N                75       1       333        2
# 4          915         1035    N                80       1       333        2
#
# [5 rows x 22 columns]

# %%
df_flights_test.columns
# Out:
# Index(['Unnamed: 0', 'fl_date', 'mkt_unique_carrier', 'branded_code_share',
#        'mkt_carrier', 'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time',
#        'crs_arr_time', 'dup', 'crs_elapsed_time', 'flights', 'distance',
#        'weekday'],
#       dtype='object')

# %%
df_flights_test.dtypes
# Out:
# Unnamed: 0                     int64
# fl_date               datetime64[ns]
# mkt_unique_carrier             int64
# branded_code_share            object
# mkt_carrier                   object
# mkt_carrier_fl_num             int64
# op_unique_carrier             object
# tail_num                      object
# op_carrier_fl_num              int64
# origin_airport_id              int64
# origin                        object
# origin_city_name              object
# dest_airport_id                int64
# dest                          object
# dest_city_name                object
# crs_dep_time                   int64
# crs_arr_time                   int64
# dup                           object
# crs_elapsed_time               int64
# flights                        int64
# distance                       int64
# weekday                        int64
# dtype: object

# %%
df_data = df_flights_test[['mkt_unique_carrier', 'mkt_carrier_fl_num', 'origin_airport_id', 'dest_airport_id', 'crs_dep_time', \
                           'crs_arr_time', 'crs_elapsed_time', 'distance']] #, 'weekday']]

# %%
df_data.columns
# Out:
# Index(['mkt_unique_carrier', 'mkt_carrier_fl_num', 'origin_airport_id',
#        'dest_airport_id', 'crs_dep_time', 'crs_arr_time', 'crs_elapsed_time',
#        'distance'],
#       dtype='object')

# %%
# Convert the dataset into an optimized data structure called Dmatrix that XGBoost supports and gives it acclaimed performance and efficiency gains.
data_dmatrix = xgb.DMatrix(data=df_data)

# %%
data_dmatrix

# %%
# And use it for predictions.
predicts = loaded_model.predict(data_dmatrix)
predicts
# Out:
# array([  7.1981263,  -6.489672 ,  29.8308   , ...,   7.727312 ,
#        -14.305009 ,  -8.031256 ], dtype=float32)

# %%
import numpy as np
np.mean(predicts)
# Out:
# -0.7495863

# %%
max(predicts), min(predicts)
# Out:
# (143.4979, -27.318256)

# %%
df_flights_test['predicted_delay'] = predicts

# %%
df_flights_test
# Out:
#         Unnamed: 0    fl_date  mkt_unique_carrier branded_code_share  \
# 0                0 2020-01-01                   9                 WN
# 1                1 2020-01-01                   9                 WN
# 2                2 2020-01-01                   9                 WN
# 3                3 2020-01-01                   9                 WN
# 4                4 2020-01-01                   9                 WN
# ...            ...        ...                 ...                ...
# 299995      299995 2020-01-15                   6                 HA
# 299996      299996 2020-01-15                   6                 HA
# 299997      299997 2020-01-15                   6                 HA
# 299998      299998 2020-01-15                   6                 HA
# 299999      299999 2020-01-15                   6                 HA
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0               WN                5888                WN   N951WN
# 1               WN                6276                WN   N467WN
# 2               WN                4598                WN   N7885A
# 3               WN                4761                WN   N551WN
# 4               WN                5162                WN   N968WN
# ...            ...                 ...               ...      ...
# 299995          HA                  38                HA   N205HA
# 299996          HA                  39                HA   N213HA
# 299997          HA                  40                HA   N215HA
# 299998          HA                  41                HA   N220HA
# 299999          HA                  42                HA   N213HA
#
#         op_carrier_fl_num  origin_airport_id  ... dest     dest_city_name  \
# 0                    5888              13891  ...  SFO  San Francisco, CA
# 1                    6276              13891  ...  SFO  San Francisco, CA
# 2                    4598              13891  ...  SJC       San Jose, CA
# 3                    4761              13891  ...  SJC       San Jose, CA
# 4                    5162              13891  ...  SJC       San Jose, CA
# ...                   ...                ...  ...  ...                ...
# 299995                 38              13830  ...  SAN      San Diego, CA
# 299996                 39              14057  ...  OGG        Kahului, HI
# 299997                 40              13830  ...  PDX       Portland, OR
# 299998                 41              14771  ...  OGG        Kahului, HI
# 299999                 42              13830  ...  SFO  San Francisco, CA
#
#         crs_dep_time crs_arr_time dup  crs_elapsed_time  flights distance  \
# 0               1810         1945   N                95        1      363
# 1               1150         1320   N                90        1      363
# 2               2020         2130   N                70        1      333
# 3               1340         1455   N                75        1      333
# 4                915         1035   N                80        1      333
# ...              ...          ...  ..               ...      ...      ...
# 299995          1210         1935   N               325        1     2541
# 299996           810         1220   N               370        1     2562
# 299997          1455         2220   N               325        1     2562
# 299998           855         1240   N               345        1     2338
# 299999          1420         2120   N               300        1     2338
#
#         weekday  predicted_delay
# 0             2         7.198126
# 1             2        -6.489672
# 2             2        29.830799
# 3             2         1.195062
# 4             2         3.401259
# ...         ...              ...
# 299995        2        -9.940062
# 299996        2       -14.305009
# 299997        2         7.727312
# 299998        2       -14.305009
# 299999        2        -8.031256
#
# [300000 rows x 23 columns]

# %%
df_flights_test.to_csv('df_flights_test_predicted.csv')
